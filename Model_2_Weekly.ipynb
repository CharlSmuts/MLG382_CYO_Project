# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %% [markdown]
# Get Data Set and Display it

# %%
data = pd.read_csv("Data/005930.KS_weekly.csv")

df = data.copy()

# 3. Plotting the Price Data (using Adj Close as the primary example)
plt.figure(figsize=(12, 6))  # Adjust figure size for better readability
plt.plot(df['Adj Close'], label='Adj Close Price', color='blue')
plt.title('Adjusted Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Adj Close Price')
plt.grid(True)
plt.legend()
plt.show()

df.dropna(inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   Open       321 non-null    float64
#  2   High       321 non-null    float64
#  3   Low        321 non-null    float64
#  4   Close      321 non-null    float64
#  5   Adj Close  321 non-null    float64
#  6   Volume     321 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 17.7+ KB

# %% [markdown]
# Processing

# %%
# Split original dataset into training and test sets while preserving original scale
train_size = int(0.8 * len(data))
train_data_original = df[:train_size]
test_data_original = df[train_size:]

# Scale features and target using MinMaxScaler
scaler_features = MinMaxScaler()
features_scaled = scaler_features.fit_transform(data[['Open', 'High', 'Low', 'Volume']])

features = df[['Open', 'High', 'Low', 'Volume']]  # Define input features


scaler_target = MinMaxScaler()
target_scaled = scaler_target.fit_transform(data[['Adj Close']])
print("NaN in target_scaled:", np.isnan(target_scaled).sum())  # Check scaled values

# Split scaled data into train and test sets
X_train = features_scaled[:train_size]
X_test = features_scaled[train_size:]
y_train = target_scaled[:train_size]
y_test = target_scaled[train_size:]
# Out:
# NaN in target_scaled: 0

# %% [markdown]
# Build Nueral Network

# %%
model = Sequential()
model.add(Dense(128, input_dim=features.shape[1], activation='relu'))  # Input layer
model.add(Dense(64, activation='relu'))  # Hidden layer
model.add(Dense(1, activation='linear'))  # Output layer

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
# Out:
# c:\Users\ruanl\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Train Model

# %%
model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0672 - mae: 0.1849 - val_loss: 0.0141 - val_mae: 0.1132
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0351 - val_loss: 0.0050 - val_mae: 0.0627
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mae: 0.0294 - val_loss: 0.0050 - val_mae: 0.0632
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mae: 0.0298 - val_loss: 0.0077 - val_mae: 0.0806
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mae: 0.0295 - val_loss: 0.0081 - val_mae: 0.0831
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mae: 0.0283 - val_loss: 0.0097 - val_mae: 0.0932
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mae: 0.0297 - val_loss: 0.0074 - val_mae: 0.0803
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mae: 0.0263 - val_loss: 0.0054 - val_mae: 0.0663
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mae: 0.0268 - val_loss: 0.0062 - val_mae: 0.0708
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mae: 0.0267 - val_loss: 0.0059 - val_mae: 0.0706
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mae: 0.0255 - val_loss: 0.0079 - val_mae: 0.0830
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mae: 0.0268 - val_loss: 0.0095 - val_mae: 0.0919
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mae: 0.0274 - val_loss: 0.0092 - val_mae: 0.0902
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mae: 0.0264 - val_loss: 0.0074 - val_mae: 0.0794
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0507e-04 - mae: 0.0242 - val_loss: 0.0058 - val_mae: 0.0700
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mae: 0.0274 - val_loss: 0.0046 - val_mae: 0.0627
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mae: 0.0244 - val_loss: 0.0053 - val_mae: 0.0668
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3285e-04 - mae: 0.0248 - val_loss: 0.0093 - val_mae: 0.0913
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6752e-04 - mae: 0.0248 - val_loss: 0.0095 - val_mae: 0.0919
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mae: 0.0270 - val_loss: 0.0055 - val_mae: 0.0675
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mae: 0.0260 - val_loss: 0.0091 - val_mae: 0.0913
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0474e-04 - mae: 0.0221 - val_loss: 0.0086 - val_mae: 0.0874
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5730e-04 - mae: 0.0233 - val_loss: 0.0044 - val_mae: 0.0576
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7305e-04 - mae: 0.0237 - val_loss: 0.0103 - val_mae: 0.0966
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7067e-04 - mae: 0.0250 - val_loss: 0.0072 - val_mae: 0.0790
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4705e-04 - mae: 0.0228 - val_loss: 0.0068 - val_mae: 0.0766
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3095e-04 - mae: 0.0219 - val_loss: 0.0098 - val_mae: 0.0925
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2305e-04 - mae: 0.0243 - val_loss: 0.0060 - val_mae: 0.0718
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8390e-04 - mae: 0.0200 - val_loss: 0.0079 - val_mae: 0.0835
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5447e-04 - mae: 0.0212 - val_loss: 0.0075 - val_mae: 0.0799
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0426e-04 - mae: 0.0228 - val_loss: 0.0073 - val_mae: 0.0800
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0853e-04 - mae: 0.0220 - val_loss: 0.0084 - val_mae: 0.0871
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0106e-04 - mae: 0.0202 - val_loss: 0.0069 - val_mae: 0.0781
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1440e-04 - mae: 0.0234 - val_loss: 0.0053 - val_mae: 0.0660
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0028e-04 - mae: 0.0232 - val_loss: 0.0068 - val_mae: 0.0762
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9754e-04 - mae: 0.0202 - val_loss: 0.0063 - val_mae: 0.0736
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4770e-04 - mae: 0.0228 - val_loss: 0.0079 - val_mae: 0.0840
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3918e-04 - mae: 0.0219 - val_loss: 0.0068 - val_mae: 0.0772
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7432e-04 - mae: 0.0237 - val_loss: 0.0129 - val_mae: 0.1092
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5413e-04 - mae: 0.0245 - val_loss: 0.0078 - val_mae: 0.0830
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4165e-04 - mae: 0.0196 - val_loss: 0.0084 - val_mae: 0.0863
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7445e-04 - mae: 0.0200 - val_loss: 0.0061 - val_mae: 0.0700
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6359e-04 - mae: 0.0215 - val_loss: 0.0084 - val_mae: 0.0858
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2214e-04 - mae: 0.0190 - val_loss: 0.0066 - val_mae: 0.0755
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5061e-04 - mae: 0.0199 - val_loss: 0.0050 - val_mae: 0.0639
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4015e-04 - mae: 0.0248 - val_loss: 0.0078 - val_mae: 0.0814
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9439e-04 - mae: 0.0219 - val_loss: 0.0087 - val_mae: 0.0877
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5377e-04 - mae: 0.0203 - val_loss: 0.0099 - val_mae: 0.0945
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0049e-04 - mae: 0.0230 - val_loss: 0.0056 - val_mae: 0.0678
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8785e-04 - mae: 0.0215 - val_loss: 0.0071 - val_mae: 0.0765

# %% [markdown]
# Predict

# %%
y_pred = model.predict(X_test)
# 4. Make predictions
predictions_scaled = model.predict(X_test)
predictions_original = scaler_target.inverse_transform(predictions_scaled)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
num_future_steps = 30  # Number of days to predict into the future
future_predictions_scaled = []
future_predictions_original = []

# Use the last training data and the test predictions to start the iterative process
last_known_features_scaled = X_test[-1:].copy() # shape (1, 4)

for _ in range(num_future_steps):
    # Predict the next step
    next_prediction_scaled = model.predict(last_known_features_scaled)
    next_prediction_original = scaler_target.inverse_transform(next_prediction_scaled)

    # Store the prediction
    future_predictions_scaled.append(next_prediction_scaled[0][0])
    future_predictions_original.append(next_prediction_original[0][0])

    # Update last_known_features_scaled for the next iteration
    #  Important:  You need to create a new input feature set for the next prediction.
    #  In this example, I'm using a simple approach:
    #  1.  Shift the existing features (Open, High, Low, Volume) one step forward
    #  2.  Use the predicted 'Adj Close' as part of the new input
    #  This is a simplification and you might need a more sophisticated way
    #  to estimate future 'Open', 'High', 'Low', and 'Volume'
    new_features_scaled = last_known_features_scaled.copy()
    new_features_scaled[0, 0] = new_features_scaled[0, 1] # Open = High
    new_features_scaled[0, 1] = new_features_scaled[0, 2] # High = Low
    new_features_scaled[0, 2] = next_prediction_scaled[0][0] # Low = Predicted Adj Close
    # For Volume, you might use the last known volume, an average, or a predicted volume.
    #  Here, I'm using the last known volume as a placeholder.  THIS IS A SIMPLIFICATION.
    new_features_scaled[0, 3] = new_features_scaled[0, 3]
    last_known_features_scaled = new_features_scaled
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# Evaluate the model

# %%
def calculate_accuracy(y_true, y_pred):
    """
    Calculates the accuracy based on Mean Absolute Percentage Error (MAPE).

    Args:
        y_true (array-like): Array of actual (true) values.
        y_pred (array-like): Array of predicted values.

    Returns:
        float: Accuracy (percentage).  Returns 0 if y_true has any zero values.
    """
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    # Handle cases with zero values in y_true to avoid division by zero
    if np.any(y_true == 0):
        print("Warning: Actual values contain zeros. MAPE and accuracy are undefined.")
        return 0.0  # Or you might want to raise an exception:  raise ValueError("Actual values cannot be zero.")

    # Calculate absolute percentage errors
    absolute_percentage_errors = np.abs((y_true - y_pred) / y_true) * 100

    # Calculate MAPE
    mape = np.mean(absolute_percentage_errors)

    # Calculate accuracy
    accuracy = 100 - mape

    return accuracy

# %%
print(f'Accuracy: {calculate_accuracy(y_test,y_pred):.2f}%')
# Out:
# Accuracy: 86.34%

# %%
all_predictions_original = np.concatenate([predictions_original.flatten(), future_predictions_original])
all_actual_original = df['Adj Close'].values  # Use the original 'Adj Close'

plt.figure(figsize=(12, 6))
plt.plot(all_actual_original, label="Actual Values", color="blue", alpha=0.7)
plt.plot(range(train_size, train_size + len(all_predictions_original)), all_predictions_original, label="Predicted Values", color="orange", alpha=0.7)
plt.xlabel("Data Points")
plt.ylabel("Adj Close")
plt.title("Actual vs Predicted Stock Prices (Extended)")
plt.legend()
plt.grid(True)
plt.show()
